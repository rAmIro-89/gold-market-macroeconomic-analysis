# %% [markdown]
# # Gold vs Macroeconomic Drivers
# This notebook will focus on relationships between gold prices and macro indicators (USD Index, real rates, inflation, oil, equities, volatility, China GDP growth, debt ratios).
